# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy.core as owm
import json
# %matplotlib inline

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

        
cities_df= pd.DataFrame(np.array(cities))
cities_df.columns = ['City']
# Print the city count to confirm sufficient count
len(cities_df)
# set up additional columns to hold information
cities_df['Cloudiness'] = ""
cities_df['Country'] = ""
cities_df['Date'] = ""
cities_df['Humidity'] = ""
cities_df['Lat'] = ""
cities_df['Lon'] = ""
cities_df['MaxTemp'] = ""
cities_df['WindSpeed'] = ""

cities_df.count()
# Out:
# City          627
# Cloudiness    627
# Country       627
# Date          627
# Humidity      627
# Lat           627
# Lon           627
# MaxTemp       627
# WindSpeed     627
# dtype: int64

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# set up lists to hold reponse info
City = []
Cloudiness = []
Country = []    
Date = []          
Humidity = []      
Lat = []           
Lon = []           
MaxTemp = []      
WindSpeed = []

# Loop through the list of cities and perform a request for data on each
for index in range(len(cities)):
    
    city = cities[index]
    
    print(f"Retrieving Results for Index {index}: {city}.")
    response = requests.get(query_url + city).json()
    try:
        #print(f"Weather For the {city_name} where country name is {response['country']}.")
        
        cities_df.loc[index, 'Cloudiness'] = response["clouds"]["all"]
        cities_df.loc[index, 'Country'] = response["sys"]["country"]
        cities_df.loc[index, 'Date'] = response['dt']
        cities_df.loc[index, 'Humidity'] = response["main"]["humidity"]
        cities_df.loc[index, 'Lat'] = response["coord"]["lat"]
        cities_df.loc[index, 'Lon'] = response["coord"]["lon"]
        cities_df.loc[index, 'MaxTemp'] = response["main"]['temp_max']
        cities_df.loc[index, 'WindSpeed'] = response["wind"]["speed"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("-------------------------------------------------------------------------")
# Out:
# Retrieving Results for Index 0: oranjemund.
# -------------------------------------------------------------------------
# Retrieving Results for Index 1: avera.
# -------------------------------------------------------------------------
# Retrieving Results for Index 2: barrow.
# -------------------------------------------------------------------------
# Retrieving Results for Index 3: rikitea.
# -------------------------------------------------------------------------
# Retrieving Results for Index 4: punta arenas.
# -------------------------------------------------------------------------
# Retrieving Results for Index 5: touros.
# -------------------------------------------------------------------------
# Retrieving Results for Index 6: nabire.
# -------------------------------------------------------------------------
# Retrieving Results for Index 7: cidreira.
# -------------------------------------------------------------------------
# Retrieving Results for Index 8: mataura.
# -------------------------------------------------------------------------
# Retrieving Results for Index 9: alofi.
# -------------------------------------------------------------------------
# Retrieving Results for Index 10: hobart.
# -------------------------------------------------------------------------
# Retrieving Results for Index 11: boyuibe.
# -------------------------------------------------------------------------
# Retrieving Results for Index 12: port augusta.
# -------------------------------------------------------------------------
# Retrieving Results for Index 13: puerto ayacucho.
# -------------------------------------------------------------------------
# Retrieving Results for Index 14: bardstown.
# -------------------------------------------------------------------------
# Retrieving Results for Index 15: conakry.
# -------------------------------------------------------------------------
# Retrieving Results for Index 16: tsaratanana.
# -------------------------------------------------------------------------
# Retrieving Results for Index 17: grand gaube.
# -------------------------------------------------------------------------
# Retrieving Results for Index 18: ribeira grande.
# -------------------------------------------------------------------------
# Retrieving Results for Index 19: barentsburg.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 20: fukue.
# -------------------------------------------------------------------------
# Retrieving Results for Index 21: ostrovnoy.
# -------------------------------------------------------------------------
# Retrieving Results for Index 22: vaini.
# -------------------------------------------------------------------------
# Retrieving Results for Index 23: upernavik.
# -------------------------------------------------------------------------
# Retrieving Results for Index 24: dikson.
# -------------------------------------------------------------------------
# Retrieving Results for Index 25: busselton.
# -------------------------------------------------------------------------
# Retrieving Results for Index 26: pingliang.
# -------------------------------------------------------------------------
# Retrieving Results for Index 27: tucumcari.
# -------------------------------------------------------------------------
# Retrieving Results for Index 28: kincardine.
# -------------------------------------------------------------------------
# Retrieving Results for Index 29: eldorado.
# -------------------------------------------------------------------------
# Retrieving Results for Index 30: pangnirtung.
# -------------------------------------------------------------------------
# Retrieving Results for Index 31: nguiu.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 32: molochnoye.
# -------------------------------------------------------------------------
# Retrieving Results for Index 33: san cristobal.
# -------------------------------------------------------------------------
# Retrieving Results for Index 34: nikolskoye.
# -------------------------------------------------------------------------
# Retrieving Results for Index 35: avarua.
# -------------------------------------------------------------------------
# Retrieving Results for Index 36: tuktoyaktuk.
# -------------------------------------------------------------------------
# Retrieving Results for Index 37: bredasdorp.
# -------------------------------------------------------------------------
# Retrieving Results for Index 38: airai.
# -------------------------------------------------------------------------
# Retrieving Results for Index 39: franklin park.
# -------------------------------------------------------------------------
# Retrieving Results for Index 40: vao.
# -------------------------------------------------------------------------
# Retrieving Results for Index 41: moba.
# -------------------------------------------------------------------------
# Retrieving Results for Index 42: jamestown.
# -------------------------------------------------------------------------
# Retrieving Results for Index 43: arraial do cabo.
# -------------------------------------------------------------------------
# Retrieving Results for Index 44: luderitz.
# -------------------------------------------------------------------------
# Retrieving Results for Index 45: bilibino.
# -------------------------------------------------------------------------
# Retrieving Results for Index 46: chuy.
# -------------------------------------------------------------------------
# Retrieving Results for Index 47: ushuaia.
# -------------------------------------------------------------------------
# Retrieving Results for Index 48: kushikino.
# -------------------------------------------------------------------------
# Retrieving Results for Index 49: zelenogorskiy.
# -------------------------------------------------------------------------
# Retrieving Results for Index 50: bathsheba.
# -------------------------------------------------------------------------
# Retrieving Results for Index 51: iqaluit.
# -------------------------------------------------------------------------
# Retrieving Results for Index 52: khor.
# -------------------------------------------------------------------------
# Retrieving Results for Index 53: hermanus.
# -------------------------------------------------------------------------
# Retrieving Results for Index 54: illoqqortoormiut.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 55: qaqortoq.
# -------------------------------------------------------------------------
# Retrieving Results for Index 56: axim.
# -------------------------------------------------------------------------
# Retrieving Results for Index 57: korla.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 58: cape town.
# -------------------------------------------------------------------------
# Retrieving Results for Index 59: siocon.
# -------------------------------------------------------------------------
# Retrieving Results for Index 60: puerto ayora.
# -------------------------------------------------------------------------
# Retrieving Results for Index 61: grindavik.
# -------------------------------------------------------------------------
# Retrieving Results for Index 62: saint-philippe.
# -------------------------------------------------------------------------
# Retrieving Results for Index 63: nizhneyansk.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 64: koutiala.
# -------------------------------------------------------------------------
# Retrieving Results for Index 65: sao joao da barra.
# -------------------------------------------------------------------------
# Retrieving Results for Index 66: torbay.
# -------------------------------------------------------------------------
# Retrieving Results for Index 67: shingu.
# -------------------------------------------------------------------------
# Retrieving Results for Index 68: jaciara.
# -------------------------------------------------------------------------
# Retrieving Results for Index 69: longyearbyen.
# -------------------------------------------------------------------------
# Retrieving Results for Index 70: concepcion del oro.
# -------------------------------------------------------------------------
# Retrieving Results for Index 71: muros.
# -------------------------------------------------------------------------
# Retrieving Results for Index 72: atuona.
# -------------------------------------------------------------------------
# Retrieving Results for Index 73: palmer.
# -------------------------------------------------------------------------
# Retrieving Results for Index 74: atar.
# -------------------------------------------------------------------------
# Retrieving Results for Index 75: urumqi.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 76: mattru.
# -------------------------------------------------------------------------
# Retrieving Results for Index 77: tessalit.
# -------------------------------------------------------------------------
# Retrieving Results for Index 78: hilo.
# -------------------------------------------------------------------------
# Retrieving Results for Index 79: luxeuil-les-bains.
# -------------------------------------------------------------------------
# Retrieving Results for Index 80: pontes e lacerda.
# -------------------------------------------------------------------------
# Retrieving Results for Index 81: marsa matruh.
# -------------------------------------------------------------------------
# Retrieving Results for Index 82: angoram.
# -------------------------------------------------------------------------
# Retrieving Results for Index 83: nador.
# -------------------------------------------------------------------------
# Retrieving Results for Index 84: kalga.
# -------------------------------------------------------------------------
# Retrieving Results for Index 85: narsaq.
# -------------------------------------------------------------------------
# Retrieving Results for Index 86: kununurra.
# -------------------------------------------------------------------------
# Retrieving Results for Index 87: maneadero.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 88: curup.
# -------------------------------------------------------------------------
# Retrieving Results for Index 89: pulaski.
# -------------------------------------------------------------------------
# Retrieving Results for Index 90: east london.
# -------------------------------------------------------------------------
# Retrieving Results for Index 91: chagda.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 92: grand river south east.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 93: lebu.
# -------------------------------------------------------------------------
# Retrieving Results for Index 94: umm durman.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 95: ponta do sol.
# -------------------------------------------------------------------------
# Retrieving Results for Index 96: araguaina.
# -------------------------------------------------------------------------
# Retrieving Results for Index 97: pochutla.
# -------------------------------------------------------------------------
# Retrieving Results for Index 98: carnarvon.
# -------------------------------------------------------------------------
# Retrieving Results for Index 99: bluff.
# -------------------------------------------------------------------------
# Retrieving Results for Index 100: pangkalanbuun.
# -------------------------------------------------------------------------
# Retrieving Results for Index 101: albany.
# -------------------------------------------------------------------------
# Retrieving Results for Index 102: nikolayevsk-na-amure.
# -------------------------------------------------------------------------
# Retrieving Results for Index 103: sitka.
# -------------------------------------------------------------------------
# Retrieving Results for Index 104: norman wells.
# -------------------------------------------------------------------------
# Retrieving Results for Index 105: yellowknife.
# -------------------------------------------------------------------------
# Retrieving Results for Index 106: malwan.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 107: caravelas.
# -------------------------------------------------------------------------
# Retrieving Results for Index 108: isangel.
# -------------------------------------------------------------------------
# Retrieving Results for Index 109: riyadh.
# -------------------------------------------------------------------------
# Retrieving Results for Index 110: thompson.
# -------------------------------------------------------------------------
# Retrieving Results for Index 111: kaitangata.
# -------------------------------------------------------------------------
# Retrieving Results for Index 112: zhigansk.
# -------------------------------------------------------------------------
# Retrieving Results for Index 113: beaverlodge.
# -------------------------------------------------------------------------
# Retrieving Results for Index 114: lompoc.
# -------------------------------------------------------------------------
# Retrieving Results for Index 115: taolanaro.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 116: buenos aires.
# -------------------------------------------------------------------------
# Retrieving Results for Index 117: hasaki.
# -------------------------------------------------------------------------
# Retrieving Results for Index 118: kapaa.
# -------------------------------------------------------------------------
# Retrieving Results for Index 119: sabha.
# -------------------------------------------------------------------------
# Retrieving Results for Index 120: gambela.
# -------------------------------------------------------------------------
# Retrieving Results for Index 121: ulaanbaatar.
# -------------------------------------------------------------------------
# Retrieving Results for Index 122: geraldton.
# -------------------------------------------------------------------------
# Retrieving Results for Index 123: tooele.
# -------------------------------------------------------------------------
# Retrieving Results for Index 124: grand-santi.
# -------------------------------------------------------------------------
# Retrieving Results for Index 125: ettenheim.
# -------------------------------------------------------------------------
# Retrieving Results for Index 126: aksu.
# -------------------------------------------------------------------------
# Retrieving Results for Index 127: kieta.
# -------------------------------------------------------------------------
# Retrieving Results for Index 128: riaba.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 129: meyungs.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 130: kilindoni.
# -------------------------------------------------------------------------
# Retrieving Results for Index 131: sambava.
# -------------------------------------------------------------------------
# Retrieving Results for Index 132: morondava.
# -------------------------------------------------------------------------
# Retrieving Results for Index 133: samusu.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 134: kodiak.
# -------------------------------------------------------------------------
# Retrieving Results for Index 135: guerrero negro.
# -------------------------------------------------------------------------
# Retrieving Results for Index 136: merauke.
# -------------------------------------------------------------------------
# Retrieving Results for Index 137: butaritari.
# -------------------------------------------------------------------------
# Retrieving Results for Index 138: mlonggo.
# -------------------------------------------------------------------------
# Retrieving Results for Index 139: port alfred.
# -------------------------------------------------------------------------
# Retrieving Results for Index 140: sao filipe.
# -------------------------------------------------------------------------
# Retrieving Results for Index 141: bulgan.
# -------------------------------------------------------------------------
# Retrieving Results for Index 142: kadykchan.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 143: manzanillo.
# -------------------------------------------------------------------------
# Retrieving Results for Index 144: tabuk.
# -------------------------------------------------------------------------
# Retrieving Results for Index 145: adrar.
# -------------------------------------------------------------------------
# Retrieving Results for Index 146: akdepe.
# -------------------------------------------------------------------------
# Retrieving Results for Index 147: mar del plata.
# -------------------------------------------------------------------------
# Retrieving Results for Index 148: amderma.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 149: lasa.
# -------------------------------------------------------------------------
# Retrieving Results for Index 150: brownsville.
# -------------------------------------------------------------------------
# Retrieving Results for Index 151: constitucion.
# -------------------------------------------------------------------------
# Retrieving Results for Index 152: verkhoyansk.
# -------------------------------------------------------------------------
# Retrieving Results for Index 153: boende.
# -------------------------------------------------------------------------
# Retrieving Results for Index 154: sancti spiritus.
# -------------------------------------------------------------------------
# Retrieving Results for Index 155: severodvinsk.
# -------------------------------------------------------------------------
# Retrieving Results for Index 156: klaksvik.
# -------------------------------------------------------------------------
# Retrieving Results for Index 157: villa carlos paz.
# -------------------------------------------------------------------------
# Retrieving Results for Index 158: lata.
# -------------------------------------------------------------------------
# Retrieving Results for Index 159: solomenskoye.
# -------------------------------------------------------------------------
# Retrieving Results for Index 160: cabo san lucas.
# -------------------------------------------------------------------------
# Retrieving Results for Index 161: belushya guba.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 162: ilulissat.
# -------------------------------------------------------------------------
# Retrieving Results for Index 163: mahebourg.
# -------------------------------------------------------------------------
# Retrieving Results for Index 164: victoria.
# -------------------------------------------------------------------------
# Retrieving Results for Index 165: najran.
# -------------------------------------------------------------------------
# Retrieving Results for Index 166: tura.
# -------------------------------------------------------------------------
# Retrieving Results for Index 167: praia da vitoria.
# -------------------------------------------------------------------------
# Retrieving Results for Index 168: bethel.
# -------------------------------------------------------------------------
# Retrieving Results for Index 169: ulladulla.
# -------------------------------------------------------------------------
# Retrieving Results for Index 170: beloha.
# -------------------------------------------------------------------------
# Retrieving Results for Index 171: port elizabeth.
# -------------------------------------------------------------------------
# Retrieving Results for Index 172: san carlos de bariloche.
# -------------------------------------------------------------------------
# Retrieving Results for Index 173: port lincoln.
# -------------------------------------------------------------------------
# Retrieving Results for Index 174: mogadishu.
# -------------------------------------------------------------------------
# Retrieving Results for Index 175: souillac.
# -------------------------------------------------------------------------
# Retrieving Results for Index 176: alice springs.
# -------------------------------------------------------------------------
# Retrieving Results for Index 177: dryden.
# -------------------------------------------------------------------------
# Retrieving Results for Index 178: provideniya.
# -------------------------------------------------------------------------
# Retrieving Results for Index 179: bording.
# -------------------------------------------------------------------------
# Retrieving Results for Index 180: bayan.
# -------------------------------------------------------------------------
# Retrieving Results for Index 181: cuamba.
# -------------------------------------------------------------------------
# Retrieving Results for Index 182: ishinomaki.
# -------------------------------------------------------------------------
# Retrieving Results for Index 183: balaipungut.
# -------------------------------------------------------------------------
# Retrieving Results for Index 184: vanavara.
# -------------------------------------------------------------------------
# Retrieving Results for Index 185: dhidhdhoo.
# -------------------------------------------------------------------------
# Retrieving Results for Index 186: vendychany.
# -------------------------------------------------------------------------
# Retrieving Results for Index 187: dwarka.
# -------------------------------------------------------------------------
# Retrieving Results for Index 188: dotnuva.
# -------------------------------------------------------------------------
# Retrieving Results for Index 189: tara.
# -------------------------------------------------------------------------
# Retrieving Results for Index 190: tiksi.
# -------------------------------------------------------------------------
# Retrieving Results for Index 191: azimur.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 192: auki.
# -------------------------------------------------------------------------
# Retrieving Results for Index 193: gorlice.
# -------------------------------------------------------------------------
# Retrieving Results for Index 194: malanje.
# -------------------------------------------------------------------------
# Retrieving Results for Index 195: buala.
# -------------------------------------------------------------------------
# Retrieving Results for Index 196: tsihombe.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 197: acucena.
# -------------------------------------------------------------------------
# Retrieving Results for Index 198: puro.
# -------------------------------------------------------------------------
# Retrieving Results for Index 199: louisbourg.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 200: kavieng.
# -------------------------------------------------------------------------
# Retrieving Results for Index 201: maues.
# -------------------------------------------------------------------------
# Retrieving Results for Index 202: marcona.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 203: fortuna.
# -------------------------------------------------------------------------
# Retrieving Results for Index 204: olafsvik.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 205: chichimila.
# -------------------------------------------------------------------------
# Retrieving Results for Index 206: yinchuan.
# -------------------------------------------------------------------------
# Retrieving Results for Index 207: sahrak.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 208: carmen.
# -------------------------------------------------------------------------
# Retrieving Results for Index 209: mareeba.
# -------------------------------------------------------------------------
# Retrieving Results for Index 210: mataram.
# -------------------------------------------------------------------------
# Retrieving Results for Index 211: hualmay.
# -------------------------------------------------------------------------
# Retrieving Results for Index 212: lenki.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 213: hithadhoo.
# -------------------------------------------------------------------------
# Retrieving Results for Index 214: umarkot.
# -------------------------------------------------------------------------
# Retrieving Results for Index 215: kailua.
# -------------------------------------------------------------------------
# Retrieving Results for Index 216: kasongo-lunda.
# -------------------------------------------------------------------------
# Retrieving Results for Index 217: kanker.
# -------------------------------------------------------------------------
# Retrieving Results for Index 218: porto novo.
# -------------------------------------------------------------------------
# Retrieving Results for Index 219: taoudenni.
# -------------------------------------------------------------------------
# Retrieving Results for Index 220: san patricio.
# -------------------------------------------------------------------------
# Retrieving Results for Index 221: ucluelet.
# -------------------------------------------------------------------------
# Retrieving Results for Index 222: olga.
# -------------------------------------------------------------------------
# Retrieving Results for Index 223: itacurubi del rosario.
# -------------------------------------------------------------------------
# Retrieving Results for Index 224: hope.
# -------------------------------------------------------------------------
# Retrieving Results for Index 225: mashhad.
# -------------------------------------------------------------------------
# Retrieving Results for Index 226: pevek.
# -------------------------------------------------------------------------
# Retrieving Results for Index 227: ughelli.
# -------------------------------------------------------------------------
# Retrieving Results for Index 228: castro.
# -------------------------------------------------------------------------
# Retrieving Results for Index 229: amahai.
# -------------------------------------------------------------------------
# Retrieving Results for Index 230: new norfolk.
# -------------------------------------------------------------------------
# Retrieving Results for Index 231: calabozo.
# -------------------------------------------------------------------------
# Retrieving Results for Index 232: tuatapere.
# -------------------------------------------------------------------------
# Retrieving Results for Index 233: gornoye loo.
# -------------------------------------------------------------------------
# Retrieving Results for Index 234: haines junction.
# -------------------------------------------------------------------------
# Retrieving Results for Index 235: chokurdakh.
# -------------------------------------------------------------------------
# Retrieving Results for Index 236: vaitupu.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 237: ancud.
# -------------------------------------------------------------------------
# Retrieving Results for Index 238: khandyga.
# -------------------------------------------------------------------------
# Retrieving Results for Index 239: kavaratti.
# -------------------------------------------------------------------------
# Retrieving Results for Index 240: kawalu.
# -------------------------------------------------------------------------
# Retrieving Results for Index 241: eskisehir.
# -------------------------------------------------------------------------
# Retrieving Results for Index 242: vardo.
# -------------------------------------------------------------------------
# Retrieving Results for Index 243: tazovskiy.
# -------------------------------------------------------------------------
# Retrieving Results for Index 244: sao joao do piaui.
# -------------------------------------------------------------------------
# Retrieving Results for Index 245: satitoa.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 246: narasannapeta.
# -------------------------------------------------------------------------
# Retrieving Results for Index 247: foix.
# -------------------------------------------------------------------------
# Retrieving Results for Index 248: actopan.
# -------------------------------------------------------------------------
# Retrieving Results for Index 249: nanortalik.
# -------------------------------------------------------------------------
# Retrieving Results for Index 250: mezen.
# -------------------------------------------------------------------------
# Retrieving Results for Index 251: saldanha.
# -------------------------------------------------------------------------
# Retrieving Results for Index 252: mikkeli.
# -------------------------------------------------------------------------
# Retrieving Results for Index 253: xai-xai.
# -------------------------------------------------------------------------
# Retrieving Results for Index 254: port blair.
# -------------------------------------------------------------------------
# Retrieving Results for Index 255: qaanaaq.
# -------------------------------------------------------------------------
# Retrieving Results for Index 256: forestville.
# -------------------------------------------------------------------------
# Retrieving Results for Index 257: jiwani.
# -------------------------------------------------------------------------
# Retrieving Results for Index 258: kazalinsk.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 259: cherskiy.
# -------------------------------------------------------------------------
# Retrieving Results for Index 260: moussoro.
# -------------------------------------------------------------------------
# Retrieving Results for Index 261: port-cartier.
# -------------------------------------------------------------------------
# Retrieving Results for Index 262: talnakh.
# -------------------------------------------------------------------------
# Retrieving Results for Index 263: saskylakh.
# -------------------------------------------------------------------------
# Retrieving Results for Index 264: coquimbo.
# -------------------------------------------------------------------------
# Retrieving Results for Index 265: balikpapan.
# -------------------------------------------------------------------------
# Retrieving Results for Index 266: yelizovo.
# -------------------------------------------------------------------------
# Retrieving Results for Index 267: neuruppin.
# -------------------------------------------------------------------------
# Retrieving Results for Index 268: mayumba.
# -------------------------------------------------------------------------
# Retrieving Results for Index 269: wanaka.
# -------------------------------------------------------------------------
# Retrieving Results for Index 270: kangundo.
# -------------------------------------------------------------------------
# Retrieving Results for Index 271: yulara.
# -------------------------------------------------------------------------
# Retrieving Results for Index 272: constantine.
# -------------------------------------------------------------------------
# Retrieving Results for Index 273: saint george.
# -------------------------------------------------------------------------
# Retrieving Results for Index 274: faanui.
# -------------------------------------------------------------------------
# Retrieving Results for Index 275: gumdag.
# -------------------------------------------------------------------------
# Retrieving Results for Index 276: mys shmidta.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 277: springbok.
# -------------------------------------------------------------------------
# Retrieving Results for Index 278: waitati.
# -------------------------------------------------------------------------
# Retrieving Results for Index 279: severo-kurilsk.
# -------------------------------------------------------------------------
# Retrieving Results for Index 280: honiara.
# -------------------------------------------------------------------------
# Retrieving Results for Index 281: shimoda.
# -------------------------------------------------------------------------
# Retrieving Results for Index 282: freeport.
# -------------------------------------------------------------------------
# Retrieving Results for Index 283: sioux lookout.
# -------------------------------------------------------------------------
# Retrieving Results for Index 284: toliary.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 285: richards bay.
# -------------------------------------------------------------------------
# Retrieving Results for Index 286: codrington.
# -------------------------------------------------------------------------
# Retrieving Results for Index 287: ikom.
# -------------------------------------------------------------------------
# Retrieving Results for Index 288: fallon.
# -------------------------------------------------------------------------
# Retrieving Results for Index 289: pakxan.
# -------------------------------------------------------------------------
# Retrieving Results for Index 290: zhuhai.
# -------------------------------------------------------------------------
# Retrieving Results for Index 291: broome.
# -------------------------------------------------------------------------
# Retrieving Results for Index 292: diofior.
# -------------------------------------------------------------------------
# Retrieving Results for Index 293: nuuk.
# -------------------------------------------------------------------------
# Retrieving Results for Index 294: georgetown.
# -------------------------------------------------------------------------
# Retrieving Results for Index 295: kerrville.
# -------------------------------------------------------------------------
# Retrieving Results for Index 296: milkovo.
# -------------------------------------------------------------------------
# Retrieving Results for Index 297: bambous virieux.
# -------------------------------------------------------------------------
# Retrieving Results for Index 298: rawson.
# -------------------------------------------------------------------------
# Retrieving Results for Index 299: havre-saint-pierre.
# -------------------------------------------------------------------------
# Retrieving Results for Index 300: pilar do sul.
# -------------------------------------------------------------------------
# Retrieving Results for Index 301: kaniama.
# -------------------------------------------------------------------------
# Retrieving Results for Index 302: esperance.
# -------------------------------------------------------------------------
# Retrieving Results for Index 303: tabou.
# -------------------------------------------------------------------------
# Retrieving Results for Index 304: valentin gomez farias.
# -------------------------------------------------------------------------
# Retrieving Results for Index 305: pouembout.
# -------------------------------------------------------------------------
# Retrieving Results for Index 306: vila franca do campo.
# -------------------------------------------------------------------------
# Retrieving Results for Index 307: luanda.
# -------------------------------------------------------------------------
# Retrieving Results for Index 308: amontada.
# -------------------------------------------------------------------------
# Retrieving Results for Index 309: ngukurr.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 310: petropavlovsk-kamchatskiy.
# -------------------------------------------------------------------------
# Retrieving Results for Index 311: tobermory.
# -------------------------------------------------------------------------
# Retrieving Results for Index 312: beira.
# -------------------------------------------------------------------------
# Retrieving Results for Index 313: presidente olegario.
# -------------------------------------------------------------------------
# Retrieving Results for Index 314: port-gentil.
# -------------------------------------------------------------------------
# Retrieving Results for Index 315: aykhal.
# -------------------------------------------------------------------------
# Retrieving Results for Index 316: tanete.
# -------------------------------------------------------------------------
# Retrieving Results for Index 317: samur.
# -------------------------------------------------------------------------
# Retrieving Results for Index 318: anklam.
# -------------------------------------------------------------------------
# Retrieving Results for Index 319: puerto madero.
# -------------------------------------------------------------------------
# Retrieving Results for Index 320: xaxim.
# -------------------------------------------------------------------------
# Retrieving Results for Index 321: helsinki.
# -------------------------------------------------------------------------
# Retrieving Results for Index 322: carutapera.
# -------------------------------------------------------------------------
# Retrieving Results for Index 323: dunedin.
# -------------------------------------------------------------------------
# Retrieving Results for Index 324: naryan-mar.
# -------------------------------------------------------------------------
# Retrieving Results for Index 325: bela.
# -------------------------------------------------------------------------
# Retrieving Results for Index 326: coihaique.
# -------------------------------------------------------------------------
# Retrieving Results for Index 327: srednekolymsk.
# -------------------------------------------------------------------------
# Retrieving Results for Index 328: hanzhong.
# -------------------------------------------------------------------------
# Retrieving Results for Index 329: wajir.
# -------------------------------------------------------------------------
# Retrieving Results for Index 330: raudeberg.
# -------------------------------------------------------------------------
# Retrieving Results for Index 331: mount gambier.
# -------------------------------------------------------------------------
# Retrieving Results for Index 332: winneba.
# -------------------------------------------------------------------------
# Retrieving Results for Index 333: aswan.
# -------------------------------------------------------------------------
# Retrieving Results for Index 334: key largo.
# -------------------------------------------------------------------------
# Retrieving Results for Index 335: hami.
# -------------------------------------------------------------------------
# Retrieving Results for Index 336: kruisfontein.
# -------------------------------------------------------------------------
# Retrieving Results for Index 337: diego de almagro.
# -------------------------------------------------------------------------
# Retrieving Results for Index 338: tasbuget.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 339: san matias.
# -------------------------------------------------------------------------
# Retrieving Results for Index 340: asau.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 341: northam.
# -------------------------------------------------------------------------
# Retrieving Results for Index 342: hay river.
# -------------------------------------------------------------------------
# Retrieving Results for Index 343: serov.
# -------------------------------------------------------------------------
# Retrieving Results for Index 344: sikonge.
# -------------------------------------------------------------------------
# Retrieving Results for Index 345: clyde river.
# -------------------------------------------------------------------------
# Retrieving Results for Index 346: fauske.
# -------------------------------------------------------------------------
# Retrieving Results for Index 347: sanchor.
# -------------------------------------------------------------------------
# Retrieving Results for Index 348: millau.
# -------------------------------------------------------------------------
# Retrieving Results for Index 349: la ronge.
# -------------------------------------------------------------------------
# Retrieving Results for Index 350: adre.
# -------------------------------------------------------------------------
# Retrieving Results for Index 351: lopsmarka.
# -------------------------------------------------------------------------
# Retrieving Results for Index 352: bubaque.
# -------------------------------------------------------------------------
# Retrieving Results for Index 353: sinnamary.
# -------------------------------------------------------------------------
# Retrieving Results for Index 354: mount isa.
# -------------------------------------------------------------------------
# Retrieving Results for Index 355: gibara.
# -------------------------------------------------------------------------
# Retrieving Results for Index 356: blue springs.
# -------------------------------------------------------------------------
# Retrieving Results for Index 357: papalotla.
# -------------------------------------------------------------------------
# Retrieving Results for Index 358: vastervik.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 359: honningsvag.
# -------------------------------------------------------------------------
# Retrieving Results for Index 360: dugna.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 361: khorinsk.
# -------------------------------------------------------------------------
# Retrieving Results for Index 362: ballina.
# -------------------------------------------------------------------------
# Retrieving Results for Index 363: pyshma.
# -------------------------------------------------------------------------
# Retrieving Results for Index 364: moisakula.
# -------------------------------------------------------------------------
# Retrieving Results for Index 365: ruatoria.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 366: byron bay.
# -------------------------------------------------------------------------
# Retrieving Results for Index 367: fuyu.
# -------------------------------------------------------------------------
# Retrieving Results for Index 368: soyo.
# -------------------------------------------------------------------------
# Retrieving Results for Index 369: pisco.
# -------------------------------------------------------------------------
# Retrieving Results for Index 370: houma.
# -------------------------------------------------------------------------
# Retrieving Results for Index 371: atasu.
# -------------------------------------------------------------------------
# Retrieving Results for Index 372: vestmannaeyjar.
# -------------------------------------------------------------------------
# Retrieving Results for Index 373: kedrovyy.
# -------------------------------------------------------------------------
# Retrieving Results for Index 374: vila velha.
# -------------------------------------------------------------------------
# Retrieving Results for Index 375: udachnyy.
# -------------------------------------------------------------------------
# Retrieving Results for Index 376: bossangoa.
# -------------------------------------------------------------------------
# Retrieving Results for Index 377: necochea.
# -------------------------------------------------------------------------
# Retrieving Results for Index 378: trenggalek.
# -------------------------------------------------------------------------
# Retrieving Results for Index 379: asyut.
# -------------------------------------------------------------------------
# Retrieving Results for Index 380: biltine.
# -------------------------------------------------------------------------
# Retrieving Results for Index 381: romanovo.
# -------------------------------------------------------------------------
# Retrieving Results for Index 382: sokoto.
# -------------------------------------------------------------------------
# Retrieving Results for Index 383: mundgod.
# -------------------------------------------------------------------------
# Retrieving Results for Index 384: khatanga.
# -------------------------------------------------------------------------
# Retrieving Results for Index 385: palencia.
# -------------------------------------------------------------------------
# Retrieving Results for Index 386: bobrov.
# -------------------------------------------------------------------------
# Retrieving Results for Index 387: te anau.
# -------------------------------------------------------------------------
# Retrieving Results for Index 388: mehamn.
# -------------------------------------------------------------------------
# Retrieving Results for Index 389: port hardy.
# -------------------------------------------------------------------------
# Retrieving Results for Index 390: santa maria.
# -------------------------------------------------------------------------
# Retrieving Results for Index 391: namibe.
# -------------------------------------------------------------------------
# Retrieving Results for Index 392: seoul.
# -------------------------------------------------------------------------
# Retrieving Results for Index 393: bonthe.
# -------------------------------------------------------------------------
# Retrieving Results for Index 394: bagdarin.
# -------------------------------------------------------------------------
# Retrieving Results for Index 395: neiafu.
# -------------------------------------------------------------------------
# Retrieving Results for Index 396: iberia.
# -------------------------------------------------------------------------
# Retrieving Results for Index 397: nang rong.
# -------------------------------------------------------------------------
# Retrieving Results for Index 398: kaduna.
# -------------------------------------------------------------------------
# Retrieving Results for Index 399: tasiilaq.
# -------------------------------------------------------------------------
# Retrieving Results for Index 400: hihifo.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 401: ban tak.
# -------------------------------------------------------------------------
# Retrieving Results for Index 402: coatesville.
# -------------------------------------------------------------------------
# Retrieving Results for Index 403: sao felix do xingu.
# -------------------------------------------------------------------------
# Retrieving Results for Index 404: katsuura.
# -------------------------------------------------------------------------
# Retrieving Results for Index 405: coahuayana.
# -------------------------------------------------------------------------
# Retrieving Results for Index 406: itamaraca.
# -------------------------------------------------------------------------
# Retrieving Results for Index 407: saint anthony.
# -------------------------------------------------------------------------
# Retrieving Results for Index 408: beringovskiy.
# -------------------------------------------------------------------------
# Retrieving Results for Index 409: ambilobe.
# -------------------------------------------------------------------------
# Retrieving Results for Index 410: qui nhon.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 411: tra vinh.
# -------------------------------------------------------------------------
# Retrieving Results for Index 412: westport.
# -------------------------------------------------------------------------
# Retrieving Results for Index 413: tamluk.
# -------------------------------------------------------------------------
# Retrieving Results for Index 414: victor harbor.
# -------------------------------------------------------------------------
# Retrieving Results for Index 415: simao.
# -------------------------------------------------------------------------
# Retrieving Results for Index 416: rawannawi.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 417: bemidji.
# -------------------------------------------------------------------------
# Retrieving Results for Index 418: along.
# -------------------------------------------------------------------------
# Retrieving Results for Index 419: kiskunmajsa.
# -------------------------------------------------------------------------
# Retrieving Results for Index 420: kayes.
# -------------------------------------------------------------------------
# Retrieving Results for Index 421: lorengau.
# -------------------------------------------------------------------------
# Retrieving Results for Index 422: russell.
# -------------------------------------------------------------------------
# Retrieving Results for Index 423: roald.
# -------------------------------------------------------------------------
# Retrieving Results for Index 424: arlit.
# -------------------------------------------------------------------------
# Retrieving Results for Index 425: lanzhou.
# -------------------------------------------------------------------------
# Retrieving Results for Index 426: dubreka.
# -------------------------------------------------------------------------
# Retrieving Results for Index 427: biak.
# -------------------------------------------------------------------------
# Retrieving Results for Index 428: dingle.
# -------------------------------------------------------------------------
# Retrieving Results for Index 429: anadyr.
# -------------------------------------------------------------------------
# Retrieving Results for Index 430: puerto escondido.
# -------------------------------------------------------------------------
# Retrieving Results for Index 431: batken.
# -------------------------------------------------------------------------
# Retrieving Results for Index 432: yambio.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 433: basco.
# -------------------------------------------------------------------------
# Retrieving Results for Index 434: maceio.
# -------------------------------------------------------------------------
# Retrieving Results for Index 435: eirunepe.
# -------------------------------------------------------------------------
# Retrieving Results for Index 436: rodrigues alves.
# -------------------------------------------------------------------------
# Retrieving Results for Index 437: gunnedah.
# -------------------------------------------------------------------------
# Retrieving Results for Index 438: lavrentiya.
# -------------------------------------------------------------------------
# Retrieving Results for Index 439: portland.
# -------------------------------------------------------------------------
# Retrieving Results for Index 440: saleaula.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 441: yerbogachen.
# -------------------------------------------------------------------------
# Retrieving Results for Index 442: itoman.
# -------------------------------------------------------------------------
# Retrieving Results for Index 443: saint peters.
# -------------------------------------------------------------------------
# Retrieving Results for Index 444: tank.
# -------------------------------------------------------------------------
# Retrieving Results for Index 445: cayenne.
# -------------------------------------------------------------------------
# Retrieving Results for Index 446: bilokurakyne.
# -------------------------------------------------------------------------
# Retrieving Results for Index 447: leninskoye.
# -------------------------------------------------------------------------
# Retrieving Results for Index 448: bilma.
# -------------------------------------------------------------------------
# Retrieving Results for Index 449: tuggurt.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 450: tawkar.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 451: linxi.
# -------------------------------------------------------------------------
# Retrieving Results for Index 452: shchelyayur.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 453: tual.
# -------------------------------------------------------------------------
# Retrieving Results for Index 454: monrovia.
# -------------------------------------------------------------------------
# Retrieving Results for Index 455: inhambane.
# -------------------------------------------------------------------------
# Retrieving Results for Index 456: ceuta.
# -------------------------------------------------------------------------
# Retrieving Results for Index 457: ampanihy.
# -------------------------------------------------------------------------
# Retrieving Results for Index 458: mlimba.
# -------------------------------------------------------------------------
# Retrieving Results for Index 459: tupiza.
# -------------------------------------------------------------------------
# Retrieving Results for Index 460: vrangel.
# -------------------------------------------------------------------------
# Retrieving Results for Index 461: ketchikan.
# -------------------------------------------------------------------------
# Retrieving Results for Index 462: garowe.
# -------------------------------------------------------------------------
# Retrieving Results for Index 463: rungata.
# Missing field/result... skipping.
# -------------------------------------------------------------------------
# Retrieving Results for Index 464: rock springs.
# -------------------------------------------------------------------------
# Retrieving Results for Index 465: koumac.

# %%
cities_df
# Out:
#                       City Cloudiness Country        Date Humidity    Lat  \
# 0               bredasdorp         68      ZA  1553260507       60 -34.53
# 1                  rikitea         44      PF  1553261100      100 -23.12
# 2             ponta do sol        100      BR  1553261100       98 -20.63
# 3              yellowknife         20      CA  1553261012       80  62.45
# 4                    bluff         44      AU  1553261100       51 -23.58
# 5           ribeira grande         40      PT  1553259600       82  38.52
# 6             puerto ayora          8      EC  1553260508       98  -0.74
# 7                esperance         20      TT  1553260649       74  10.24
# 8                 el bagre         80      CO  1553261101       97    7.6
# 9                   hobart         75      AU  1553261054       82 -42.88
# 10               busselton          0      AU  1553260930       44 -33.64
# 11                     gao         64      ML  1553261101       17  16.28
# 12                  broome         75      GB  1553261080       81  52.47
# 13                hermanus         56      ZA  1553260507       66 -34.42
# 14                  awbari          0      LY  1553261102       32  26.59
# 15                saleaula
# 16   los llanos de aridane         40      ES  1553260802       52  28.66
# 17             ciro marina          0      IT  1553259000       63  39.37
# 18    vila franca do campo         40      PT  1553260948       82  37.72
# 19                  atuona         68      PF  1553261103      100   -9.8
# 20                 klichka          8      RU  1553261103       36  50.44
# 21              butaritari         88      KI  1553261103      100   3.07
# 22          kulhudhuffushi          8      MV  1553261103      100   6.62
# 23                benguela          0      AO  1553261103       81 -12.58
# 24          guerrero negro         36      MX  1553261104       99  27.97
# 25                thompson         75      CA  1553259600       92  55.74
# 26                 ushuaia         75      AR  1553256000       93 -54.81
# 27             clyde river         90      CA  1553259600       67  70.47
# 28                  barrow         76      AR  1553261104       71 -38.31
# 29                    tura          0      IN  1553261105       58  25.52
# ..                     ...        ...     ...         ...      ...    ...
# 612           porto walter         64      BR  1553261214       96  -8.27
# 613              whitianga        100      NZ  1553261111       97 -36.83
# 614         cabo san lucas          5      MX  1553261134       45  22.89
# 615                  rafai         56      CF  1553261214       40   4.95
# 616                 rusape         24      ZW  1553261214       75 -18.53
# 617                 trelew          0      AR  1553261215       65 -43.25
# 618                 ekhabi         48      RU  1553261215       86  53.51
# 619              boguchany         92      RU  1553261215       67  58.38
# 620             srivardhan          0      IN  1553261215       49  18.03
# 621        dzilam gonzalez          0      MX  1553261215       84  21.28
# 622                  areka          0      ET  1553261215       20   7.07
# 623                 bayeux          0      FR  1553259600       58  49.28
# 624                mareeba         40      AU  1553261118       88 -16.99
# 625                 tekeli          0      KZ  1553261216       71  44.86
# 626              formigine          0      IT  1553261199       37  44.58
# 627            kjollefjord         40      NO  1553259000       82  70.95
# 628                  amapa         75      HN  1553259600       94  15.09
# 629            kloulklubed         75      PW  1553255400       83   7.04
# 630           spirit river         20      CA  1553260930       85  55.78
# 631              crab hill
# 632                 rawdon         90      CA  1553261198      100  46.05
# 633               belmonte          0      PT  1553260574       36  40.36
# 634                    eyl          0      SO  1553261217       78   7.98
# 635              williston          1      US  1553260925       79  48.15
# 636          palabuhanratu
# 637                aksarka          8      RU  1553261218       86  66.56
# 638                 neiafu         75      TO  1553259600       83 -18.65
# 639            itacoatiara         20      BR  1553259600       83  -3.14
# 640                 jieshi         92      CN  1553260922       11  22.82
# 641              boyolangu         88      ID  1553261218       96  -8.09
#
#         Lon MaxTemp WindSpeed
# 0     20.04      75     11.41
# 1   -134.97   78.49     14.12
# 2       -46   64.99      11.1
# 3   -114.38    30.2      9.17
# 4    149.07   81.28     11.77
# 5     -28.7    62.6      5.82
# 6    -90.35      75      2.71
# 7    -61.45   82.99      8.05
# 8     -74.8   74.53      2.93
# 9    147.33    62.6      8.05
# 10   115.35   60.01     25.08
# 11    -0.04   91.36     12.21
# 12     1.45      54     14.99
# 13    19.24      75        14
# 14    12.77   72.91     12.77
# 15
# 16   -17.92    69.8     16.11
# 17    17.13    62.6     14.99
# 18   -25.43    60.8      8.05
# 19  -139.03   81.37     14.12
# 20      118   19.99     10.42
# 21   172.79   79.21      5.73
# 22    73.07   84.97      8.63
# 23     13.4   87.22      8.19
# 24  -114.04   54.28     13.22
# 25   -97.86    12.2      3.36
# 26   -68.31    44.6      3.36
# 27   -68.59  -22.01      2.24
# 28   -60.23   54.91     10.31
# 29    90.21   78.13      4.94
# ..      ...     ...       ...
# 612  -72.74   73.18      2.93
# 613   175.7      64       5.5
# 614 -109.91      68      2.24
# 615   23.92   94.87      9.98
# 616   32.12      73      6.62
# 617  -65.31    55.9     12.44
# 618  142.97    2.26      9.08
# 619   97.46   36.37     10.65
# 620   73.02   87.22      9.75
# 621  -88.93   63.55      4.16
# 622   37.71   88.57      3.04
# 623    -0.7      59      2.24
# 624  145.42      77     11.41
# 625   78.76   50.32      2.37
# 626   10.85   69.01      5.82
# 627   27.35    33.8     34.45
# 628  -87.97    71.6      2.24
# 629  134.26      77      3.36
# 630 -118.84   30.99      2.24
# 631
# 632  -73.71      37      6.93
# 633   -7.35      64      1.99
# 634   49.82   83.35     10.98
# 635 -103.62    30.2      8.41
# 636
# 637    67.8   20.35      6.51
# 638 -173.98      77      5.82
# 639  -58.44    80.6      3.36
# 640  115.83      68     17.69
# 641   111.9   72.01      2.59
#
# [642 rows x 9 columns]

# %%
cities_df.to_csv('cities_weather_data.csv')

cities_data = "cities_weather_data.csv"

# Read the City and Ride Data
csv_city_data_df = pd.read_csv(cities_data)

csv_city_data_df
# Out:
#      Unnamed: 0                   City  Cloudiness Country          Date  \
# 0             0             bredasdorp        68.0      ZA  1.553261e+09
# 1             1                rikitea        44.0      PF  1.553261e+09
# 2             2           ponta do sol       100.0      BR  1.553261e+09
# 3             3            yellowknife        20.0      CA  1.553261e+09
# 4             4                  bluff        44.0      AU  1.553261e+09
# 5             5         ribeira grande        40.0      PT  1.553260e+09
# 6             6           puerto ayora         8.0      EC  1.553261e+09
# 7             7              esperance        20.0      TT  1.553261e+09
# 8             8               el bagre        80.0      CO  1.553261e+09
# 9             9                 hobart        75.0      AU  1.553261e+09
# 10           10              busselton         0.0      AU  1.553261e+09
# 11           11                    gao        64.0      ML  1.553261e+09
# 12           12                 broome        75.0      GB  1.553261e+09
# 13           13               hermanus        56.0      ZA  1.553261e+09
# 14           14                 awbari         0.0      LY  1.553261e+09
# 15           15               saleaula         NaN     NaN           NaN
# 16           16  los llanos de aridane        40.0      ES  1.553261e+09
# 17           17            ciro marina         0.0      IT  1.553259e+09
# 18           18   vila franca do campo        40.0      PT  1.553261e+09
# 19           19                 atuona        68.0      PF  1.553261e+09
# 20           20                klichka         8.0      RU  1.553261e+09
# 21           21             butaritari        88.0      KI  1.553261e+09
# 22           22         kulhudhuffushi         8.0      MV  1.553261e+09
# 23           23               benguela         0.0      AO  1.553261e+09
# 24           24         guerrero negro        36.0      MX  1.553261e+09
# 25           25               thompson        75.0      CA  1.553260e+09
# 26           26                ushuaia        75.0      AR  1.553256e+09
# 27           27            clyde river        90.0      CA  1.553260e+09
# 28           28                 barrow        76.0      AR  1.553261e+09
# 29           29                   tura         0.0      IN  1.553261e+09
# ..          ...                    ...         ...     ...           ...
# 612         612           porto walter        64.0      BR  1.553261e+09
# 613         613              whitianga       100.0      NZ  1.553261e+09
# 614         614         cabo san lucas         5.0      MX  1.553261e+09
# 615         615                  rafai        56.0      CF  1.553261e+09
# 616         616                 rusape        24.0      ZW  1.553261e+09
# 617         617                 trelew         0.0      AR  1.553261e+09
# 618         618                 ekhabi        48.0      RU  1.553261e+09
# 619         619              boguchany        92.0      RU  1.553261e+09
# 620         620             srivardhan         0.0      IN  1.553261e+09
# 621         621        dzilam gonzalez         0.0      MX  1.553261e+09
# 622         622                  areka         0.0      ET  1.553261e+09
# 623         623                 bayeux         0.0      FR  1.553260e+09
# 624         624                mareeba        40.0      AU  1.553261e+09
# 625         625                 tekeli         0.0      KZ  1.553261e+09
# 626         626              formigine         0.0      IT  1.553261e+09
# 627         627            kjollefjord        40.0      NO  1.553259e+09
# 628         628                  amapa        75.0      HN  1.553260e+09
# 629         629            kloulklubed        75.0      PW  1.553255e+09
# 630         630           spirit river        20.0      CA  1.553261e+09
# 631         631              crab hill         NaN     NaN           NaN
# 632         632                 rawdon        90.0      CA  1.553261e+09
# 633         633               belmonte         0.0      PT  1.553261e+09
# 634         634                    eyl         0.0      SO  1.553261e+09
# 635         635              williston         1.0      US  1.553261e+09
# 636         636          palabuhanratu         NaN     NaN           NaN
# 637         637                aksarka         8.0      RU  1.553261e+09
# 638         638                 neiafu        75.0      TO  1.553260e+09
# 639         639            itacoatiara        20.0      BR  1.553260e+09
# 640         640                 jieshi        92.0      CN  1.553261e+09
# 641         641              boyolangu        88.0      ID  1.553261e+09
#
#      Humidity    Lat     Lon  MaxTemp  WindSpeed
# 0        60.0 -34.53   20.04    75.00      11.41
# 1       100.0 -23.12 -134.97    78.49      14.12
# 2        98.0 -20.63  -46.00    64.99      11.10
# 3        80.0  62.45 -114.38    30.20       9.17
# 4        51.0 -23.58  149.07    81.28      11.77
# 5        82.0  38.52  -28.70    62.60       5.82
# 6        98.0  -0.74  -90.35    75.00       2.71
# 7        74.0  10.24  -61.45    82.99       8.05
# 8        97.0   7.60  -74.80    74.53       2.93
# 9        82.0 -42.88  147.33    62.60       8.05
# 10       44.0 -33.64  115.35    60.01      25.08
# 11       17.0  16.28   -0.04    91.36      12.21
# 12       81.0  52.47    1.45    54.00      14.99
# 13       66.0 -34.42   19.24    75.00      14.00
# 14       32.0  26.59   12.77    72.91      12.77
# 15        NaN    NaN     NaN      NaN        NaN
# 16       52.0  28.66  -17.92    69.80      16.11
# 17       63.0  39.37   17.13    62.60      14.99
# 18       82.0  37.72  -25.43    60.80       8.05
# 19      100.0  -9.80 -139.03    81.37      14.12
# 20       36.0  50.44  118.00    19.99      10.42
# 21      100.0   3.07  172.79    79.21       5.73
# 22      100.0   6.62   73.07    84.97       8.63
# 23       81.0 -12.58   13.40    87.22       8.19
# 24       99.0  27.97 -114.04    54.28      13.22
# 25       92.0  55.74  -97.86    12.20       3.36
# 26       93.0 -54.81  -68.31    44.60       3.36
# 27       67.0  70.47  -68.59   -22.01       2.24
# 28       71.0 -38.31  -60.23    54.91      10.31
# 29       58.0  25.52   90.21    78.13       4.94
# ..        ...    ...     ...      ...        ...
# 612      96.0  -8.27  -72.74    73.18       2.93
# 613      97.0 -36.83  175.70    64.00       5.50
# 614      45.0  22.89 -109.91    68.00       2.24
# 615      40.0   4.95   23.92    94.87       9.98
# 616      75.0 -18.53   32.12    73.00       6.62
# 617      65.0 -43.25  -65.31    55.90      12.44
# 618      86.0  53.51  142.97     2.26       9.08
# 619      67.0  58.38   97.46    36.37      10.65
# 620      49.0  18.03   73.02    87.22       9.75
# 621      84.0  21.28  -88.93    63.55       4.16
# 622      20.0   7.07   37.71    88.57       3.04
# 623      58.0  49.28   -0.70    59.00       2.24
# 624      88.0 -16.99  145.42    77.00      11.41
# 625      71.0  44.86   78.76    50.32       2.37
# 626      37.0  44.58   10.85    69.01       5.82
# 627      82.0  70.95   27.35    33.80      34.45
# 628      94.0  15.09  -87.97    71.60       2.24
# 629      83.0   7.04  134.26    77.00       3.36
# 630      85.0  55.78 -118.84    30.99       2.24
# 631       NaN    NaN     NaN      NaN        NaN
# 632     100.0  46.05  -73.71    37.00       6.93
# 633      36.0  40.36   -7.35    64.00       1.99
# 634      78.0   7.98   49.82    83.35      10.98
# 635      79.0  48.15 -103.62    30.20       8.41
# 636       NaN    NaN     NaN      NaN        NaN
# 637      86.0  66.56   67.80    20.35       6.51
# 638      83.0 -18.65 -173.98    77.00       5.82
# 639      83.0  -3.14  -58.44    80.60       3.36
# 640      11.0  22.82  115.83    68.00      17.69
# 641      96.0  -8.09  111.90    72.01       2.59
#
# [642 rows x 10 columns]

# %%
# Build a scatter plot for each data type
plt.scatter(csv_city_data_df['Lat'], csv_city_data_df['MaxTemp'], marker="o", facecolors= 'skyblue', edgecolors="black", alpha=0.75)

plt.title("City Latitude vs. Max Temprature (Fri, 22 Mar 2019)")
plt.ylabel("Max Temprature (F)")
plt.xlabel("Latitude")
plt.grid(True)


# Save the figure
plt.savefig("City Latitude vs. Max Temprature.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(csv_city_data_df['Lat'], csv_city_data_df['Humidity'], marker="o", facecolors= 'skyblue', edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (Fri, 22 Mar 2019)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("City Latitude vs. Humidity.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(csv_city_data_df['Lat'], csv_city_data_df['Cloudiness'], marker="o", facecolors= 'skyblue', edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (Fri, 22 Mar 2019)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("City Latitude vs. Cloudiness.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(csv_city_data_df['Lat'], csv_city_data_df['WindSpeed'], marker="o", facecolors= 'skyblue', edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. WindSpeed (Fri, 22 Mar 2019)")
plt.ylabel("WindSpeed (MPH)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("City Latitude vs. WindSpeed.png")

# Show plot
plt.show()
